# %% [markdown]
# part 1
#
# Beijing is a city with rich culture and long history. There are almost 30,000 restaurants opened in Beijing so that opening a restaurant is becoming more and more competitive. In this Capstone project, I will use the Foursquare API, looking at the usercount and tipcount, to find the best location to open a restaurant in Beijing. what place is popular to attract people and what place has the most reviews. Why this place is best to choose to open a restaurant. I will also try to compare with other popular restaruants. I hope this project will help people who want to find a suitable place to open the restaurant.

# %% [markdown]
# part 2
#
# Data

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Get longitude and latitude for Beijing
address = 'Beijing, Beijing'

geolocator = Nominatim(user_agent="Beijing_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Beijing is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Beijing is 39.906217, 116.3912757.

# %%
# Set up Foursquare
CLIENT_ID = 'ZPASLTVAI5CMIH00DQTEA2C4NPTWSMSXGMB1IGDFUOVLF2XR' # your Foursquare ID
CLIENT_SECRET = 'O5QNF22HJHPTBPQAH3GNYEULNIKJRMN04LMTNIQRB2L4C4GE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZPASLTVAI5CMIH00DQTEA2C4NPTWSMSXGMB1IGDFUOVLF2XR
# CLIENT_SECRET:O5QNF22HJHPTBPQAH3GNYEULNIKJRMN04LMTNIQRB2L4C4GE

# %%
search_query = 'Restaurant'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ZPASLTVAI5CMIH00DQTEA2C4NPTWSMSXGMB1IGDFUOVLF2XR&client_secret=O5QNF22HJHPTBPQAH3GNYEULNIKJRMN04LMTNIQRB2L4C4GE&ll=39.906217,116.3912757&v=20180605&query=Restaurant&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 2  [{'id': '52af0bd33cf9994f4e043bdd', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
#
#                          id    location.address location.cc location.city  \
# 0  50d3fbeae4b0c79b932cee1d    88 Wangfujing St          CN           北京市
# 1  4d6f81c65b5ca1cd8d326d44                 NaN          CN           NaN
# 2  4ba5ad7af964a5205f1b39e3           王府井大街198号          CN           北京市
# 3  51a6da0c498eefec4f2773f5  198  Wangfujing St          CN           北京市
# 4  52f472a7498e71aef5aded9f   138 Wangfujing St          CN           北京市
#
#   location.country    location.crossStreet  location.distance  \
# 0               中国  at 7/F of Intime Lotte               1504
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                  name           categories  \
# 0  Meizhou Dongpo Restaurant (眉州东坡酒楼)  Szechuan Restaurant
# 1          Western Sichuan Restaurant   Chinese Restaurant
# 2    Dong Lai Shun Restaurant (东来顺饭庄)    Hotpot Restaurant
# 3      Dong Li Shun Muslim Restaurant   Chinese Restaurant
# 4             青柠 Lime Thai Restaurant      Thai Restaurant
#
#               address  cc city country             crossStreet  distance  \
# 0    88 Wangfujing St  CN  北京市      中国  at 7/F of Intime Lotte      1504
# 1                 NaN  CN  NaN      中国                     NaN        55
# 2           王府井大街198号  CN  北京市      中国                     NaN      1272
# 3  198  Wangfujing St  CN  北京市      中国                     NaN      1253
# 4   138 Wangfujing St  CN  北京市      中国   at 5/F of Beijing apm      1485
#
#                                     formattedAddress  \
# 0  [88 Wangfujing St (at 7/F of Intime Lotte), 北京...
# 1                                               [中国]
# ...

# %%
# !pip install folium

# %%
import folium

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
